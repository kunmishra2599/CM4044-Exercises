# %% [markdown]
# ## Matplotlib Exercise
#
# For this exercise, we are using Matplotlib to visualize Company Sales Data, which is stored in a text file, "company_sales_data.csv". It is available in NTULearn.
#
# The data file has 9 columns of data with a header for every column's name:
#
# "month_number","facecream","facewash","toothpaste","bathingsoap","shampoo","moisturizer","total_units","total_profit"

# %% [markdown]
# ### 1.
# Read total profit of all months from "company_sales_data.csv" and show it using a line plot:
#
# Total profit data provided for each month. Generated line plot must include the following properties: –
#
# - X label name = Month
# - Y label name = Total profit
# - figure title: Company profit per month
# - x ticks: month number
# - y ticks: 100000, 200000, 300000, 400000, 500000
#
# Solution:

# %%
## Solution 1
## use plt package
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt("company_sales_data.csv", delimiter = ",", skip_header = 1, dtype = int)
# print(data)
profits = data[:,8]
# print(profits)

# %matplotlib inline    

x = data[:,0]
y = profits
plt.plot(x,y)

plt.xlabel("Month")
plt.ylabel("Total Profit")
plt.xticks(data[:,0])
plt.title("Company profit per month")
plt.yticks([100000, 200000, 300000, 400000, 500000])
plt.show()

# %%
## Solution 2
# use OOP (figure and axes) to draw the plot

fig = plt.figure(figsize=(4,3), dpi=100)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax.plot(x, y, color="blue", linewidth=1.0, linestyle="-")
ax.set_xticks(data[:,0])
ax.set_yticks([100000, 200000, 300000, 400000, 500000])
ax.set_title("Company profit per month")
ax.set_xlabel("Month")
ax.set_ylabel("Total Profit")

plt.show()

# %% [markdown]
# ### 2.
#
# Generated line plot for company profit data to include following Style properties:
#
# - Line Style dotted and Line-color should be red
# - Show legend at the lower right location. Legent text: Profit data of last year
# - X label name = Month
# - Y label name = Total Profit
# - Add a circle marker.
# - Line marker color as read
# - Line width should be 3
#
# Solution:

# %%
## Solution 1
## use plt package
plt.plot(data[:,0],data[:,8], linestyle = "dotted", color = "red", marker = "o", linewidth = 3, label = "Profit data of last year")
plt.figlegend(loc = "lower right")
plt.xlabel("Month")
plt.ylabel("Total Profit")
plt.xticks(data[:,0])
plt.show()

# %%
## Solution 2
# use OOP (figure and axes) to draw the plot
fig = plt.figure(figsize=(5,4), dpi=80)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax.plot(data[:,0],data[:,7], color="red", linewidth=3.0, linestyle="dotted", marker = "o", label = "Profit data of last year")
ax.set_xticks(data[:,0])
ax.set_xlabel("Month")
ax.set_ylabel("Sold Units number")
ax.legend(loc="lower right")


plt.show()

# %% [markdown]
# ### 3.
#
# Read all product sales data and show it using a multiline plot:
#
# Display the number of units sold per month for each product using multiline plots. (i.e., separate Plotline for each product for each product).
#
# - every line has different colour
# - linewidth 3
# - use cicle as data marker
# - show the legend on the upper left corner of the plot
# - legend text "xxxx Sales Data", xxxx is the goods item name, such as face cream, Toothpaste, etc.
# - x label "Month"
# - y label "Sales units in number"
# - figure title "Sales data"
# - xticks: month number
# - yticks: 1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000
#
# Solution:

# %%
## Solution 1
## use plt package

plt.plot(data[:,0],data[:,1], linestyle = "dotted", marker = "o", linewidth = 3, label = "facecream")
plt.plot(data[:,0],data[:,2], linestyle = "dotted", marker = "o", linewidth = 3, label = "facewash")
plt.plot(data[:,0],data[:,3], linestyle = "dotted", marker = "o", linewidth = 3, label = "toothpaste")
plt.plot(data[:,0],data[:,4], linestyle = "dotted", marker = "o", linewidth = 3, label = "bathingsoap")
plt.plot(data[:,0],data[:,5], linestyle = "dotted", marker = "o", linewidth = 3, label = "shampoo")
plt.plot(data[:,0],data[:,6], linestyle = "dotted", marker = "o", linewidth = 3, label = "moisturiser")

plt.legend(bbox_to_anchor=(0, 1), loc = "upper left", prop = {'size': 9})
plt.xlabel("Month")
plt.ylabel("Sales unit in number")
plt.title("Sales data")
plt.xticks(data[:,0])
plt.yticks([1000,2000,4000,6000,8000,10000,12000,15000,18000])
plt.show()

# %%
## Solution 2
# use OOP (figure and axes) to draw the plot
fig = plt.figure(figsize=(5,4), dpi=80)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax.plot(data[:,0],data[:,1], linestyle = "dotted", marker = "o", linewidth = 3, label = "facecream")
ax.plot(data[:,0],data[:,2], linestyle = "dotted", marker = "o", linewidth = 3, label = "facewash")
ax.plot(data[:,0],data[:,3], linestyle = "dotted", marker = "o", linewidth = 3, label = "toothpaste")
ax.plot(data[:,0],data[:,4], linestyle = "dotted", marker = "o", linewidth = 3, label = "bathingsoap")
ax.plot(data[:,0],data[:,5], linestyle = "dotted", marker = "o", linewidth = 3, label = "shampoo")
ax.plot(data[:,0],data[:,6], linestyle = "dotted", marker = "o", linewidth = 3, label = "moisturiser")
ax.set_xticks(data[:,0])
ax.set_yticks([1000,2000,4000,6000,8000,10000,12000,15000,18000])
ax.set_xlabel("Month")
ax.set_ylabel("Sales unit in number")
ax.set_title("Sales data")
ax.legend(loc="upper left",  prop = {'size': 9})


plt.show()

# %% [markdown]
# ### 4.
#
# Read toothpaste sales data of each month and show it using a scatter plot. Add a grid in the plot and Gridline style should “–“.
#
# - scatter point in purple colour
# - use cicle as data marker
# - show the legend on the upper left corner of the plot
# - legend text "Tooth paste Sales Data"
# - x label "Month"
# - y label "Sales units in number"
# - figure title "Tooth paste Sales data"
# - xticks: month number
# - yticks: use system default value
#
# Solution:

# %%
## Solution 21
# use plt package to draw the plot
plt.scatter(data[:,0],data[:,3], color = "purple", marker = "o", label = "Tooth paste Sales Data")
plt.figlegend(loc = "upper left")
plt.xlabel("Month")
plt.ylabel("Sales unit in number")
plt.title("Tooth paste Sales data")
plt.xticks(data[:,0])
plt.grid(True, linestyle = "-")
plt.show()

# %%
## Solution 2
# use OOP (figure and axes) to draw the plot
fig = plt.figure(figsize=(5,4), dpi=80)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax.scatter(data[:,0],data[:,3], color = "purple", marker = "o", label = "Tooth paste Sales data")
ax.set_xticks(data[:,0])
ax.set_xlabel("Month")
ax.set_ylabel("Sales unit in number")
ax.set_title("Tooth paste Sales data")
ax.legend(loc="upper left")
ax.grid(True, linestyle = "-")


plt.show()

# %% [markdown]
# ### 5.
#
# Read face cream and face wash product sales data and show it using the bar chart. Bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# - legend text: "Face Cream Sales Data" and "Face Wash Sales Data"
# - legend position well so that legend will not overlap with bars in the plot
# - x label "Month"
# - y label "Sales units in number"
# - figure title "Facewash and FaceCream Sales Data"
# - xticks: month
# - yticks: use system default value
#
# Solution:

# %%
## Solution 1
# use plt package to draw the plot
plt.bar(data[:,0]-0.125,data[:,1], label = "Face Cream Sales Data", width = 0.25, align = "center")
plt.bar(data[:,0]+0.125,data[:,2], label = "Face Wash Sales Data", width = 0.25, align = "center")
plt.xlabel("Month")
plt.ylabel("Sales units in number")
plt.title("Facewash and Facecream Sales Data")
plt.legend(bbox_to_anchor=(1, 1))
plt.xticks(data[:,0])
plt.show()

# %%
## Solution 2
# use OOP (figure and axes) to draw the plot
fig = plt.figure(figsize=(5,5), dpi=80)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax.bar(data[:,0]-0.125,data[:,1], label = "Face Cream Sales Data", width = 0.25, align = "center")
ax.bar(data[:,0]+0.125,data[:,2], label = "Face Wash Sales Data", width = 0.25, align = "center")
ax.set_xticks(data[:,0])
ax.set_xlabel("Month")
ax.set_ylabel("Sales unit in number")
ax.set_title("Facewash and Facecream Sales data")
ax.legend(bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### 6.
#
# Read the total profit of each month and show it using the histogram to see most common profit ranges
#
# - The bins: 150000, 175000, 200000, 225000, 250000, 300000, 350000
# - x label : Profit range in dollar
# - y label : Actual Profit in dolar
# - legend on the best corner
# - title: Profit data
#
# Solution:

# %%
## Solution 1
# use plt package to draw the plot
plt.hist(data[:,8], bins = [150000, 175000, 200000, 225000, 250000, 300000, 350000], label = "Profit data")
plt.figlegend(loc = "best")
plt.xlabel("Profit range in dollar")
plt.ylabel("Actual Profit in dollar")
plt.title("Profit data")
plt.show()
# Out:
# C:\Users\kunmi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Automatic legend placement (loc='best') not implemented for figure legend. Falling back on 'upper right'. This will raise an exception in 3.3.
#   after removing the cwd from sys.path.

# %%
## Solution 2
# use OOP (figure and axes) to draw the plot
fig = plt.figure(figsize=(8,5), dpi=80)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax.hist(data[:,8], bins = [150000, 175000, 200000, 225000, 250000, 300000, 350000], label = "Profit data")
ax.set_xlabel("Profit range in dollar")
ax.set_ylabel("Actual profit in dollar")
ax.set_title("Profit data")
ax.legend(loc="best")

plt.show()

# %% [markdown]
# ### 7.
#
# Use subplots to display sales data for Bathingsoap, Facewash, Facecream and Toothpaste.
#
# Solution:

# %%
## The best solution
# use OOP (figure and axes) to draw the plot

fig, ax = plt.subplots(2,2, figsize=(14,12))
ax = ax.flatten()

ax[0].plot(data[:,0],data[:,4], linestyle = "dotted", marker = "o", linewidth = 3, label = "bathingsoap")
ax[1].plot(data[:,0],data[:,1], linestyle = "dotted", marker = "o", linewidth = 3, label = "facecream")
ax[2].plot(data[:,0],data[:,2], linestyle = "dotted", marker = "o", linewidth = 3, label = "facewash")
ax[3].plot(data[:,0],data[:,3], linestyle = "dotted", marker = "o", linewidth = 3, label = "toothpaste")

titles  = ["bathingsoap", "facecream", "facewash", "toothpaste"]
for x in range(len(ax)):
    ax[x].set_xlabel("Month")
    ax[x].set_ylabel("Sales unit in number")
    ax[x].set_title(titles[x])

plt.show()

# %% [markdown]
# ### 8.
#
# Read all product sales data and show them using the stack plot.
#
# - legend is on best position, so that it doesn't overlap with plot
# - different colours are used for different product
# - Figure Title: All product sales data in stack plot
# - x title: Month
# - y title: Sales units in number
#
# Solution:

# %%
## Solution 1
# use OOP (figure and axes) to draw the plot
fig = plt.figure(figsize=(12,7), dpi=80)
ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

ax.stackplot(data[:,0],data[:,1],data[:,2],data[:,3],data[:,4],data[:,5],data[:,6], labels= ["facecream", "facewash", "toothpaste","bathingsoap","shampoo", "moisturiser"])

ax.set_xlabel("Month")
ax.set_xticks(data[:,0])
ax.set_xlim(1,12)
ax.set_ylabel("Sales unit in number")
ax.set_title("All product sales in stack plot")
ax.legend(loc="best", prop = {'size':10}, bbox_to_anchor=(0.17, 0.98) )

plt.show()
